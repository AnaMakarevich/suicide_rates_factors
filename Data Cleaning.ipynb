# %%
import pandas as pd

# %% [markdown]
# # Suicide Rates Dataset

# %% [markdown]
# Suicide rate:
# Age-standardized suicide rates (per 100 000 population)

# %%
suicides = pd.read_csv('suicide_core.csv').iloc[1:,0:3]

# %%
suicides.columns = ['country','sex','suicide_rate']

# %%
female_suicides = suicides[suicides.sex == 'Female'][['country','suicide_rate']]

# %%
female_suicides = female_suicides.assign(country = female_suicides.country.apply(lambda x: x.strip()))

# %%
len(female_suicides)
# Out:
# 183

# %%
female_suicides.head()
# Out:
#                 country  suicide_rate
# 3           Afghanistan           3.1
# 6               Albania           2.4
# 9               Algeria           1.3
# 12               Angola          14.3
# 15  Antigua and Barbuda           0.0

# %% [markdown]
# Check if there are null values:

# %%
female_suicides.suicide_rate.isnull().sum()
# Out:
# 0

# %% [markdown]
# # Drinks

# %%
drinks = pd.read_csv('drinks.csv')

# %%
drinks_total = drinks[['country','total_litres_of_pure_alcohol']]

# %%
drinks_total = drinks_total.assign(country = drinks_total.country.apply(lambda x: x.strip()))

# %%
len(drinks_total)
# Out:
# 193

# %%
drinks_total.head()
# Out:
#        country  total_litres_of_pure_alcohol
# 0  Afghanistan                           0.0
# 1      Albania                           4.9
# 2      Algeria                           0.7
# 3      Andorra                          12.4
# 4       Angola                           5.9

# %% [markdown]
# Check if there are null values

# %%
drinks.total_litres_of_pure_alcohol.isnull().sum()
# Out:
# 0

# %% [markdown]
# # GDI

# %%
gdi = pd.read_excel('GDI.xlsx')

# %%
gdi.columns
# Out:
# Index(['HDI rank', 'Country', 'GDI Value(2015)', 'GDI Group(2015)',
#        'HDI Female(2015)', 'Expected schooling years Female(2015)',
#        'Estimated GNI per capita -Female(2015)'],
#       dtype='object')

# %%
gdi_selection = gdi[['Country', 'GDI Value(2015)', 'HDI Female(2015)', 'Expected schooling years Female(2015)',
    'Estimated GNI per capita -Female(2015)']]

# %%
gdi_selection.columns = ['country','gdi', 'hdi', 'schooling_years','gni']

# %%
gdi_selection = gdi_selection.assign(country = gdi_selection.country.apply(lambda x: x.strip()))

# %%
gdi_selection.head()
# Out:
#                     country    gdi    hdi  schooling_years   gni
# 0               South Sudan  0.874  0.370              3.8  1286
# 1                   Eritrea  0.874  0.370              4.4  1286
# 2                     Niger  0.732  0.291              4.7   481
# 3  Central African Republic  0.776  0.306              5.8   482
# 4                      Chad  0.765  0.340              5.8  1581

# %% [markdown]
# Check if there are missing values

# %%
gdi_selection.isnull().sum()
# Out:
# country            0
# gdi                0
# hdi                0
# schooling_years    0
# gni                0
# dtype: int64

# %% [markdown]
# # Poverty

# %% [markdown]
# For poverty data sets we took the most recent years and imputed the data for 2014 from the years 2011-2013. For those that don't have any values for any years, we took the column average.
# TODO: add rationale (i.e. the remaining countires intuitively are good fit for the mean)

# %%
poverty = pd.read_excel('poverty.xlsx')
poverty_selection = poverty[['Country', 2014]]
poverty_selection.columns = ['country', 'poverty_index']
poverty_selection = poverty_selection.assign(country = poverty_selection.country.apply(lambda x: x.strip()))
poor_countries = poverty_selection['country']
means = poverty_selection["poverty_index"].fillna(poverty_selection["poverty_index"].mean())
poverty_selection = poverty_selection.assign(poverty_index = means)
poverty_selection.head()
# Out:
#        country  poverty_index
# 0  Afghanistan       0.293000
# 1      Albania       0.156609
# 2    Argentina       0.156609
# 3      Armenia       0.156609
# 4   Azerbaijan       0.156609

# %% [markdown]
# # Happiness

# %% [markdown]
# Life satisfaction is measured on a scale from 0 to 10 (0 - worst, 10 - best).

# %%
happiness = pd.read_csv('happiness.csv')
happiness = happiness.assign(country = happiness.country.apply(lambda x: x.strip()))
happiness.columns
# Out:
# Index(['country', 'satisfaction_index'], dtype='object')

# %%
happiness[happiness.satisfaction_index.isnull()].head()
# Out:
#                 country  satisfaction_index
# 2               Algeria                 NaN
# 3                Angola                 NaN
# 4   Antigua and Barbuda                 NaN
# 5            Arab World                 NaN
# 11              Bahamas                 NaN

# %% [markdown]
# Rationale for missing values. Values are missing only for the poor, undeveloped countires. Examples of them are Algeria, Angola. In the previous dataset on poverty we had only poor and hence unhappy countries (TODO: add link to research that shows that richer -> happier in general). So we're going to select all the countries that are considered poor and take their average for imputation.

# %%
poor_countries_mean = pd.merge(pd.DataFrame(poor_countries), happiness, how='left').satisfaction_index.mean()

# %%
happiness.fillna(poor_countries_mean, inplace = True)

# %%
happiness.head()
# Out:
#                country  satisfaction_index
# 0          Afghanistan            3.982855
# 1              Albania            4.606651
# 2              Algeria            4.792081
# 3               Angola            4.792081
# 4  Antigua and Barbuda            4.792081

# %% [markdown]
# # Unemployement rates

# %%
unempl = pd.read_excel('unemployement_rates.xlsx')

# %%
unempl_selection = unempl[['Country Name', 2015]]
unempl_selection.columns = ['country', 'unemployment_rate']

# %%
unempl_selection.unemployment_rate.isnull().sum()
# Out:
# 0

# %%
unempl_selection.head()
# Out:
#                 country  unemployment_rate
# 0           Afghanistan                8.6
# 1                Angola                6.2
# 2               Albania               17.1
# 3  United Arab Emirates                4.0
# 4             Argentina                7.2

# %%
unempl_selection.unemployment_rate.sum()
# Out:
# 649888.061718299

# %% [markdown]
# # Health services

# %%
health = pd.read_csv("health_services.csv")

# %%
health_selection = health.iloc[:,[0,2]]
health_selection.columns = ['country', 'access_to_family_planning']

# %%
health_selection.head()
# Out:
#                country  access_to_family_planning
# 0          Afghanistan                       47.0
# 1              Albania                       12.9
# 2              Algeria                       77.2
# 3               Angola                       24.2
# 4  Antigua and Barbuda                       58.2

# %% [markdown]
# # GII

# %%
gii = pd.read_excel('GII.xlsx')

# %%
gii
# Out:
#                     Country  GII Value  GII Rank  \
# 0               Afghanistan      0.667       154
# 1                   Albania      0.267        51
# 2                   Algeria      0.429        94
# 3                   Andorra      0.078        14
# 4                    Angola      0.672       155
# 5       Antigua and Barbuda      0.354        74
# 6                 Argentina      0.362        77
# 7                   Armenia      0.293        61
# 8                 Australia      0.120        24
# 9                   Austria      0.078        14
# 10               Azerbaijan      0.326        68
# 11                  Bahamas      0.362        77
# 12                  Bahrain      0.233        48
# 13               Bangladesh      0.520       119
# 14                 Barbados      0.291        59
# 15                  Belarus      0.144        32
# 16                  Belgium      0.073        12
# 17                   Belize      0.375        81
# 18                    Benin      0.613       144
# 19                   Bhutan      0.477       110
# 20                  Bolivia      0.446        98
# 21   Bosnia and Herzegovina      0.158        34
# 22                 Botswana      0.435        95
# 23                   Brazil      0.414        92
# 24                  Brunei       0.179        39
# 25                 Bulgaria      0.223        45
# 26             Burkina Faso      0.615       146
# 27                  Burundi      0.474       108
# 28               Cabo Verde      0.672       155
# 29                 Cambodia      0.479       112
# ..                      ...        ...       ...
# 165               Sri Lanka      0.386        87
# 166                   Sudan      0.575       140
# 167                Suriname      0.448        99
# 168               Swaziland      0.566       137
# 169                  Sweden      0.048         4
# 170             Switzerland      0.040         1
# 171                   Syria      0.554       133
# 172              Tajikistan      0.322        65
# 173                Tanzania      0.544       129
# 174                Thailand      0.366        79
# 175                   Timor      0.448        99
# 176                    Togo      0.556       134
# 177                   Tonga      0.659       152
# 178     Trinidad and Tobago      0.324        67
# 179                 Tunisia      0.289        58
# 180                  Turkey      0.328        69
# 181            Turkmenistan      0.278        53
# 182                  Tuvalu      0.659       152
# 183                  Uganda      0.522       121
# 184                 Ukraine      0.284        55
# 185    United Arab Emirates      0.232        46
# 186                 Uruguay      0.284        55
# 187                     USA      0.203        43
# 188              Uzbekistan      0.287        57
# 189                 Vanuatu      0.366        79
# 190               Venezuela      0.461       101
# 191                 Vietnam      0.337        71
# 192                   Yemen      0.767       159
# 193                  Zambia      0.526       124
# 194                Zimbabwe      0.540       126
#
#     Maternal mortality ratio (deaths per 100,000 live births)  \
# 0                                                  396
# 1                                                   29
# 2                                                  140
# 3                                                    4
# 4                                                  477
# 5                                                   45
# 6                                                   52
# 7                                                   25
# 8                                                    6
# 9                                                    4
# 10                                                  25
# 11                                                  80
# 12                                                  15
# 13                                                 176
# 14                                                  27
# 15                                                   4
# 16                                                   7
# 17                                                  28
# 18                                                 405
# 19                                                 148
# 20                                                 206
# 21                                                  11
# 22                                                 129
# 23                                                  44
# 24                                                  23
# 25                                                  11
# 26                                                 371
# 27                                                 712
# 28                                                  42
# 29                                                 161
# ..                                                 ...
# 165                                                 30
# 166                                                311
# 167                                                155
# 168                                                389
# 169                                                  4
# 170                                                  5
# 171                                                 68
# 172                                                 32
# 173                                                398
# 174                                                 20
# 175                                                215
# 176                                                368
# 177                                                124
# 178                                                 63
# 179                                                 62
# 180                                                 16
# 181                                                 42
# 182                                                100
# 183                                                343
# 184                                                 24
# 185                                                  6
# 186                                                 15
# 187                                                 14
# 188                                                 36
# 189                                                 78
# 190                                                 95
# 191                                                 54
# 192                                                385
# 193                                                224
# 194                                                443
#
#      Adolescent birth rate (birth per 1,000 women ages 15-19)  \
# 0                                                 74.0
# 1                                                 21.7
# 2                                                 10.6
# 3                                                  7.1
# 4                                                164.3
# 5                                                 44.8
# 6                                                 63.8
# 7                                                 23.0
# 8                                                 14.1
# 9                                                  7.1
# 10                                                59.8
# 11                                                29.6
# 12                                                13.5
# 13                                                83.0
# 14                                                40.7
# 15                                                18.2
# 16                                                 8.2
# 17                                                65.9
# 18                                                83.2
# 19                                                21.4
# 20                                                70.8
# 21                                                 8.6
# 22                                                32.3
# 23                                                67.0
# 24                                                21.0
# 25                                                37.7
# 26                                               108.5
# 27                                                28.3
# 28                                                73.4
# 29                                                51.6
# ..                                                 ...
# 165                                               14.8
# 166                                               74.0
# 167                                               46.1
# 168                                               70.4
# 169                                                5.7
# 170                                                2.9
# 171                                               39.4
# 172                                               38.1
# 173                                              118.6
# 174                                               44.6
# 175                                               46.6
# 176                                               92.0
# 177                                               15.2
# 178                                               31.5
# 179                                                6.8
# 180                                               27.6
# 181                                               16.4
# 182                                               15.0
# 183                                              111.9
# 184                                               24.1
# 185                                               29.7
# 186                                               56.1
# 187                                               22.6
# 188                                               17.7
# 189                                               43.1
# 190                                               79.4
# 191                                               38.6
# 192                                               61.5
# 193                                               90.4
# 194                                              109.7
#
#      Labour force participation rate(% ages 15 and older)
# 0                                                 19.1
# 1                                                 40.3
# 2                                                 16.8
# 3                                                 54.7
# 4                                                 59.9
# 5                                                 56.0
# 6                                                 48.4
# 7                                                 54.9
# 8                                                 58.6
# 9                                                 54.7
# 10                                                61.9
# 11                                                69.4
# 12                                                39.2
# 13                                                43.1
# 14                                                62.4
# 15                                                54.5
# 16                                                48.2
# 17                                                56.3
# 18                                                70.0
# 19                                                58.7
# 20                                                63.9
# 21                                                34.4
# 22                                                73.4
# 23                                                56.3
# 24                                                51.0
# 25                                                48.6
# 26                                                76.6
# 27                                                84.6
# 28                                                53.2
# 29                                                75.5
# ..                                                 ...
# 165                                               30.2
# 166                                               24.3
# 167                                               40.5
# 168                                               40.0
# 169                                               60.9
# 170                                               62.7
# 171                                               12.2
# 172                                               59.4
# 173                                               74.0
# 174                                               62.9
# 175                                               26.8
# 176                                               81.1
# 177                                               52.8
# 178                                               52.6
# 179                                               25.1
# 180                                               30.4
# 181                                               47.3
# 182                                               44.0
# 183                                               82.3
# 184                                               52.2
# 185                                               41.9
# 186                                               55.4
# 187                                               56.0
# 188                                               48.3
# 189                                               61.6
# 190                                               51.4
# 191                                               73.8
# 192                                               25.8
# 193                                               69.8
# 194                                               77.8
#
# [195 rows x 6 columns]
